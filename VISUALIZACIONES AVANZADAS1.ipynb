# %% [markdown]
# ---

# %% [markdown]
# TIPOS DE DATOS "CATEGORY"

# %%
import pandas as pd

# %%
import os
os.getcwd()  # Otra manera
# Out:
# 'C:\\Users\\Zene'

# %%
datos = pd.read_csv('C://Users//Zene//Documents//aa INTILIGENCIA ARTIFICIAL//bloque 2 Python a-z//5.Data Frames//Recursos archivos//RatingsPeliculas.csv')

# %%
datos
# Out:
#                   Pelicula    Genero  Ratings de Rotten Tomatoes %  \
# 0    (500) Days of Summer    Comedia                            87
# 1              10,000 B.C.  Aventura                             9
# 2               12 Rounds     Accion                            30
# 3                127 Hours  Aventura                            93
# 4                17 Again    Comedia                            55
# ..                     ...       ...                           ...
# 554          Your Highness   Comedia                            26
# 555        Youth in Revolt   Comedia                            68
# 556                 Zodiac  Suspenso                            89
# 557            Zombieland     Accion                            90
# 558              Zookeeper   Comedia                            14
#
#      Ratings de la Audience %  Presupuesto (millones USD)  Lanzamiento
# 0                          81                           8         2009
# ...

# %%
peliculas = pd.read_csv('RatingsPeliculas.csv')

# %%
len(peliculas)
# Out:
# 559

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  Ratings de Rotten Tomatoes %  \
# 0  (500) Days of Summer    Comedia                            87
# 1            10,000 B.C.  Aventura                             9
# 2             12 Rounds     Accion                            30
# 3              127 Hours  Aventura                            93
# 4              17 Again    Comedia                            55
#
#    Ratings de la Audience %  Presupuesto (millones USD)  Lanzamiento
# 0                        81                           8         2009
# 1                        44                         105         2008
# 2                        52                          20         2009
# 3                        84                          18         2010
# 4                        70                          20         2009

# %%
peliculas.columns
# Out:
# Index(['Pelicula', 'Genero', 'Ratings de Rotten Tomatoes %',
#        'Ratings de la Audience %', 'Presupuesto (millones USD)',
#        'Lanzamiento'],
#       dtype='object')

# %%
peliculas.columns = ['Pelicula', 'Genero', 'RatingsCriticos','RatingsAudience', 
                    'PresupuestoMillones', 'Año']

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  RatingsCriticos  RatingsAudience  \
# 0  (500) Days of Summer    Comedia               87               81
# 1            10,000 B.C.  Aventura                9               44
# 2             12 Rounds     Accion               30               52
# 3              127 Hours  Aventura               93               84
# 4              17 Again    Comedia               55               70
#
#    PresupuestoMillones   Año
# 0                    8  2009
# 1                  105  2008
# 2                   20  2009
# 3                   18  2010
# 4                   20  2009

# %%
peliculas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Pelicula             559 non-null    object
#  1   Genero               559 non-null    object
#  2   RatingsCriticos      559 non-null    int64
#  3   RatingsAudience      559 non-null    int64
#  4   PresupuestoMillones  559 non-null    int64
#  5   Año                  559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
peliculas.describe()
# Out:
#        RatingsCriticos  RatingsAudience  PresupuestoMillones          Año
# count       559.000000       559.000000           559.000000   559.000000
# mean         47.309481        58.744186            50.236136  2009.152057
# std          26.413091        16.826887            48.731817     1.362632
# min           0.000000         0.000000             0.000000  2007.000000
# 25%          25.000000        47.000000            20.000000  2008.000000
# 50%          46.000000        58.000000            35.000000  2009.000000
# 75%          70.000000        72.000000            65.000000  2010.000000
# max          97.000000        96.000000           300.000000  2011.000000

# %%
# Variable convertimos a datos categoricos

# %%
peliculas.Pelicula = peliculas.Pelicula.astype('category')

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  RatingsCriticos  RatingsAudience  \
# 0  (500) Days of Summer    Comedia               87               81
# 1            10,000 B.C.  Aventura                9               44
# 2             12 Rounds     Accion               30               52
# 3              127 Hours  Aventura               93               84
# 4              17 Again    Comedia               55               70
#
#    PresupuestoMillones   Año
# 0                    8  2009
# 1                  105  2008
# 2                   20  2009
# 3                   18  2010
# 4                   20  2009

# %%
peliculas.Genero = peliculas.Genero.astype('category')

# %%
peliculas.head()
# Out:
#                 Pelicula    Genero  RatingsCriticos  RatingsAudience  \
# 0  (500) Days of Summer    Comedia               87               81
# 1            10,000 B.C.  Aventura                9               44
# 2             12 Rounds     Accion               30               52
# 3              127 Hours  Aventura               93               84
# 4              17 Again    Comedia               55               70
#
#    PresupuestoMillones   Año
# 0                    8  2009
# 1                  105  2008
# 2                   20  2009
# 3                   18  2010
# 4                   20  2009

# %%
peliculas.Genero = peliculas.Genero.astype('category')
peliculas.Año = peliculas.Año.astype('category')

# %%
peliculas.Genero.cat.categories
# Out:
# Index(['Accion', 'Aventura', 'Comedia', 'Drama', 'Romance', 'Suspenso',
#        'Terror'],
#       dtype='object')

# %%
peliculas.describe()
# Out:
#        RatingsCriticos  RatingsAudience  PresupuestoMillones
# count       559.000000       559.000000           559.000000
# mean         47.309481        58.744186            50.236136
# std          26.413091        16.826887            48.731817
# min           0.000000         0.000000             0.000000
# 25%          25.000000        47.000000            20.000000
# 50%          46.000000        58.000000            35.000000
# 75%          70.000000        72.000000            65.000000
# max          97.000000        96.000000           300.000000

# %% [markdown]
# ---

# %% [markdown]
# TRABAJANDO CON  JointPlots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# JointPlots

# %%
j = sns.jointplot(data=peliculas, x="RatingsCriticos", y="RatingsAudience")

# %%
# Grafico 1
j = sns.jointplot(data=peliculas, x="RatingsCriticos", y="RatingsAudience", kind='hex')

# %% [markdown]
# ---

# %% [markdown]
# HISTOGRAMAS

# %%
m1 = sns.distplot(peliculas.RatingsAudience, bins=15)

# %%
#Diagrama 1
m1 = sns.distplot(peliculas.RatingsCriticos, bins=15)

# %%
# Diagrama 2
ni=plt.hist(peliculas.RatingsAudience, bins=15)

# %%
# Diagrama 3
ni=plt.hist(peliculas.RatingsCriticos, bins=15)

# %%
# Diagrama 4
# Lista para almacenar los datos
lista1 = []
mis_etiquetas = []

# Asegúrate de que 'Genero' es una categoría y 'PresupuestoMillones' es una columna en el DataFrame
for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero == gen]['PresupuestoMillones'])
    mis_etiquetas.append(gen)

# Crear el histograma
plt.hist(lista1, bins=30, stacked=True, rwidth=1, label=mis_etiquetas)

# Añadir leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# CREANDO UN DIAGRAMA     KDE

# %%
vis1 = sns.lmplot(data=peliculas, x='RatingsCriticos', y= 'RatingsAudience',
                 fit_reg=False, hue='Genero',height=6, aspect=1)

# %%
k1 = sns.jointplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, kind='kde')

k1.plot_joint(sns.kdeplot, fill=True)

# %%
K2 = sns.jointplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, kind='kde')

k1.plot_joint(sns.kdeplot, shade=True, shade_lowest=False)

# %%
# Crear el gráfico conjunto
k2 = sns.jointplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, kind='kde', cmap='Reds')

# Ajustar las propiedades del gráfico
k2.plot_joint(sns.kdeplot, shade=True, cmap='Reds')

# Establecer el fondo cuadriculado
plt.grid(True)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# TRABAJANDO CON   SUBPLOTS

# %%
# Trabajando con subplots()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
K2 = sns.jointplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, kind='kde')

k1.plot_joint(sns.kdeplot, shade=True, shade_lowest=False)

# %%
# Crear el gráfico conjunto
k2 = sns.jointplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, kind='kde', cmap='Reds')

# Ajustar las propiedades del gráfico
k2.plot_joint(sns.kdeplot, shade=True, cmap='Reds')

# Establecer el fondo cuadriculado
plt.grid(True)

plt.show()

# %%
# Crear el gráfico conjunto
k2 = sns.jointplot(x='PresupuestoMillones', y='RatingsCriticos', data=peliculas, kind='kde', cmap='Reds')

# Ajustar las propiedades del gráfico
k2.plot_joint(sns.kdeplot, shade=True, cmap='Reds')

# Establecer el fondo cuadriculado
plt.grid(True)

plt.show()

# %%
# Crear subplots
f, ax = plt.subplots(1, 2, figsize=(12, 6))

# Primer gráfico
sns.kdeplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, shade=True, ax=ax[0], cmap='Greens')
ax[0].set_title('Presupuesto y Ratings de Audiencia')

# Segundo gráfico
sns.kdeplot(x='PresupuestoMillones', y='RatingsCriticos', data=peliculas, shade=True, ax=ax[1], cmap='Greens')
ax[1].set_title('Presupuesto y Ratings de Críticos')

# Mostrar los gráficos
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear subplots
f, ax = plt.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True)

# Primer gráfico
sns.kdeplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, shade=True, ax=ax[0], cmap='Blues')
ax[0].set_title('Presupuesto y Ratings de Audiencia')

# Segundo gráfico
sns.kdeplot(x='PresupuestoMillones', y='RatingsCriticos', data=peliculas, shade=True, ax=ax[1], cmap='Blues')
ax[1].set_title('Presupuesto y Ratings de Críticos')

# Mostrar los gráficos
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# VIOLINPLOTS  CONTRA BOXPLOT

# %%
# Diagramas de Violin

# %%
z=sns.violinplot(data=peliculas,x='Genero', y='RatingsCriticos')

# %%
z=sns.boxplot(data=peliculas,x='Genero', y='RatingsCriticos')

# %%
# Crear el boxplot
w = sns.boxplot(data=peliculas[peliculas.Genero == 'Drama'], x='Año', y='RatingsCriticos')

# Mostrar el gráfico
plt.show()

# %%
w = sns.violinplot(data=peliculas[peliculas.Genero == 'Drama'], x='Año', y='RatingsCriticos')

# %% [markdown]
# ---

# %% [markdown]
# CREANDO FACETGRID

# %%
g=sns.FacetGrid(peliculas, row='Genero', col='Año', hue='Genero')
g = g.map(plt.scatter,'RatingsCriticos', 'RatingsAudience')

# %%
# Se puede rellenar con cualquier tipo de gráfico. Ejemplo:HISTOGRAMA

# %%
g=sns.FacetGrid(peliculas, row='Genero', col='Año', hue='Genero')
g = g.map(plt.hist,'PresupuestoMillones')

# %%
# Crear un objeto FacetGrid
g = sns.FacetGrid(peliculas, row='Genero', col='Año', hue='Genero')

# Definir los parámetros para los puntos de dispersión
kws = dict(s=50, linewidth=0.5, edgecolor='black')

# Mapear el scatter plot
g = g.map(plt.scatter, 'RatingsCriticos', 'RatingsAudience', **kws)

# Añadir leyenda
g.add_legend()

# Mostrar los gráficos
plt.show()

# %%
# g = g.map()

# %%
plt.scatter(peliculas.RatingsCriticos, peliculas.RatingsAudience)

# %% [markdown]
# ---

# %% [markdown]
# CORDENADAS Y DIAGONALES

# %%
# Crear un objeto FacetGrid
g = sns.FacetGrid(peliculas, row='Genero', col='Año', hue='Genero')

# Definir los parámetros para los puntos de dispersión
kws = dict(s=50, linewidth=0.5, edgecolor='black')

# Mapear el scatter plot
g = g.map(plt.scatter, 'RatingsCriticos', 'RatingsAudience', **kws)

# Controlando ejes y agregando diagonales
g.set(xlim=(0, 100), ylim=(0, 100))

for ax in g.axes.flat: ax.plot((0, 100), (0, 100), c='gray', ls='--')

# Añadir leyenda
g.add_legend()

# Mostrar los gráficos
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# CONSTRUIENDO DESHBOARDS BONUS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Configurar el estilo
sns.set_style("darkgrid")

# Crear subplots
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Primer gráfico KDE
k1 = sns.kdeplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, shade=True, ax=axes[0, 0], cmap='Blues')
axes[0, 0].set_title('Presupuesto y Ratings de Audiencia')

# Segundo gráfico KDE
k2 = sns.kdeplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, shade=True, ax=axes[0, 1], cmap='Blues')
axes[0, 1].set_title('Presupuesto y Ratings de Críticos')

# Tercer gráfico Violin Plot
sns.violinplot(data=peliculas[peliculas.Genero == 'Drama'], x='Año', y='RatingsCriticos', ax=axes[1, 0])
axes[1, 0].set_title('Ratings de Críticos por Año en Drama')

# Cuarto gráfico KDE
k4 = sns.kdeplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, shade=True, shade_lowest=False, cmap='Greens', ax=axes[1, 1])
k4b = sns.kdeplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, cmap='Greens', ax=axes[1, 1])
axes[1, 1].set_title('Ratings de Críticos y Audiencia')

# Establecer los límites x
axes[0, 0].set_xlim(-20, 160)
axes[0, 1].set_xlim(-20, 160)

# Mostrar los gráficos
plt.show()

# %%
# Configurar el estilo
sns.set_style("darkgrid")

# Crear subplots
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Primer gráfico KDE
k1 = sns.kdeplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, shade=True, shade_lowest=True, cmap='inferno', ax=axes[0, 0])
axes[0, 0].set_title('Presupuesto y Ratings de Audiencia')

# Segundo gráfico KDE
k2 = sns.kdeplot(x='PresupuestoMillones', y='RatingsCriticos', data=peliculas, shade=True, shade_lowest=True, cmap='inferno', ax=axes[0, 1])
axes[0, 1].set_title('Presupuesto y Ratings de Críticos')

# Tercer gráfico Violin Plot con paleta de colores 'inferno'
sns.violinplot(data=peliculas[peliculas.Genero == 'Drama'], x='Año', y='RatingsCriticos', ax=axes[1, 0], palette='inferno')
axes[1, 0].set_title('Ratings de Críticos por Año en Drama')

# Cuarto gráfico KDE con fondo color inferno
k4 = sns.kdeplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, shade=True, shade_lowest=False, cmap='inferno', ax=axes[1, 1])
k4b = sns.kdeplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, cmap='cool', ax=axes[1, 1])
axes[1, 1].set_title('Ratings de Críticos y Audiencia')

# Establecer los límites x
axes[0, 0].set_xlim(-35, 260)
axes[0, 1].set_xlim(-35, 260)

# Mostrar los gráficos
plt.show()

# %%
# Configurar el estilo
sns.set_style("dark",{"axes.facecolor":"black"})

# Crear subplots
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Primer gráfico KDE
k1 = sns.kdeplot(x='PresupuestoMillones', y='RatingsAudience', data=peliculas, shade=True, shade_lowest=True, cmap='inferno', ax=axes[0, 0])
axes[0, 0].set_title('Presupuesto y Ratings de Audiencia')

# Segundo gráfico KDE
k2 = sns.kdeplot(x='PresupuestoMillones', y='RatingsCriticos', data=peliculas, shade=True, shade_lowest=True, cmap='inferno', ax=axes[0, 1])
axes[0, 1].set_title('Presupuesto y Ratings de Críticos')

# Tercer gráfico Violin Plot con paleta de colores 'inferno'
sns.violinplot(data=peliculas[peliculas.Genero == 'Drama'], x='Año', y='RatingsCriticos', palette='inferno', ax=axes[1, 0])
axes[1, 0].set_title('Ratings de Críticos por Año en Drama')

# Cuarto gráfico KDE con fondo correcto
k4 = sns.kdeplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, shade=True, shade_lowest=True, cmap='inferno', ax=axes[1, 1])
k4b = sns.kdeplot(x='RatingsCriticos', y='RatingsAudience', data=peliculas, cmap='cool', ax=axes[1, 1])
axes[1, 1].set_title('Ratings de Críticos y Audiencia')

# Establecer los límites x
axes[0, 0].set_xlim(-35, 260)
axes[0, 1].set_xlim(-35, 260)

# Mostrar los gráficos
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# Cambios tematicos

# %%
# Lista para almacenar los datos
lista1 = []
mis_etiquetas = []

# Asegúrate de que 'Genero' es una categoría y 'PresupuestoMillones' es una columna en el DataFrame
for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero == gen]['PresupuestoMillones'])
    mis_etiquetas.append(gen)

# Crear el histograma
plt.hist(lista1, bins=30, stacked=True, rwidth=1, label=mis_etiquetas)

# Añadir leyenda
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
# Lista para almacenar los datos
sns.set_style("whitegrid")
lista1 = []
mis_etiquetas = []

# Asegúrate de que 'Genero' es una categoría y 'PresupuestoMillones' es una columna en el DataFrame
for gen in peliculas.Genero.cat.categories:
    lista1.append(peliculas[peliculas.Genero == gen]['PresupuestoMillones'])
    mis_etiquetas.append(gen)

fig, ax = plt.subplots(1, 1)
fig.set_size_inches(11.7, 8.27)  # Tamaño de una hoja A4

h = plt.hist(lista1, bins=30, stacked=True, rwidth=1, edgecolor = 'none', label=mis_etiquetas)
plt.title('Distribución de Presupuestos para las Peliculas',fontsize=35, color="DarkBlue")
plt.ylabel("Número de peliculas", fontsize=25, color='Red')
plt.xlabel("Presupuesto",fontsize=25, color="Green")
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
# Añadir leyenda
plt.legend(frameon=True, fancybox=True, framealpha=1, shadow=True, prop={'size':20})

# Mostrar el gráfico
plt.show()
